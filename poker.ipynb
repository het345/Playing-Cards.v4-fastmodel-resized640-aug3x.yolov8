# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect model = train model=yolov8l.pt conf = 0.75 source = '/Users/hetan2/Desktop/Playing Cards.v4-fastmodel-resized640-aug3x.yolov8/data.yaml' epochs = 50 imgsz = 640
# Out:
# WARNING ⚠️ 'mode' argument is missing. Valid modes are {'track', 'export', 'predict', 'benchmark', 'train', 'val'}. Using default 'mode=train'.
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# New https://pypi.org/project/ultralytics/8.3.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.23 🚀 Python-3.11.5 torch-2.5.0 CPU (Apple M2)
# ...
